# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv

# %%
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', 1000)
from sklearn.metrics import mean_absolute_error
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
train = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
test = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
from collections import Counter
num_col = train.loc[:,'MSSubClass':'SaleCondition'].select_dtypes(exclude=['object']).columns
# Outlier detection 

def detect_outliers(df,n,features):
    """
    Takes a dataframe df of features and returns a list of the indices
    corresponding to the observations containing more than n outliers according
    to the Tukey method.
    """
    outlier_indices = []
    
    # iterate over features(columns)
    for col in features:
        # 1st quartile (25%)
        Q1 = np.percentile(df[col], 25)
        # 3rd quartile (75%)
        Q3 = np.percentile(df[col],75)
        # Interquartile range (IQR)
        IQR = Q3 - Q1
        
        # outlier step
        outlier_step = 1.5 * IQR
        
        # Determine a list of indices of outliers for feature col
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step )].index
        
        # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
        
    # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    
    return multiple_outliers   

# detect outliers from Age, SibSp , Parch and Fare
Outliers_to_drop = detect_outliers(train,2, num_col)
train.loc[Outliers_to_drop] # Show the outliers rows
# Drop outliers
train = train.drop(Outliers_to_drop, axis = 0).reset_index(drop=True)

# %%
df = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'], test.loc[:,'MSSubClass':'SaleCondition']))

# %%
# before tuning
def basic_details(df):
    b = pd.DataFrame()
    b['Missing value'] = df.isnull().sum()
    b['N unique value'] = df.nunique()
    b['dtype'] = df.dtypes
    return b
basic_details(df)
# Out:
#                Missing value  N unique value    dtype
# MSSubClass                 0              16    int64
# MSZoning                   4               5   object
# LotFrontage              456             127  float64
# LotArea                    0            1872    int64
# Street                     0               2   object
# Alley                   2611               2   object
# LotShape                   0               4   object
# LandContour                0               4   object
# Utilities                  2               1   object
# LotConfig                  0               5   object
# LandSlope                  0               3   object
# Neighborhood               0              25   object
# Condition1                 0               9   object
# Condition2                 0               7   object
# BldgType                   0               5   object
# HouseStyle                 0               8   object
# OverallQual                0              10    int64
# OverallCond                0               9    int64
# YearBuilt                  0             114    int64
# YearRemodAdd               0              61    int64
# RoofStyle                  0               6   object
# RoofMatl                   0               7   object
# Exterior1st                1              15   object
# Exterior2nd                1              16   object
# MasVnrType                23               4   object
# MasVnrArea                22             429  float64
# ExterQual                  0               4   object
# ExterCond                  0               5   object
# Foundation                 0               6   object
# BsmtQual                  75               4   object
# BsmtCond                  76               4   object
# BsmtExposure              76               4   object
# BsmtFinType1              73               6   object
# BsmtFinSF1                 1             961  float64
# BsmtFinType2              74               6   object
# BsmtFinSF2                 1             248  float64
# BsmtUnfSF                  1            1111  float64
# TotalBsmtSF                1            1026  float64
# Heating                    0               6   object
# HeatingQC                  0               5   object
# CentralAir                 0               2   object
# Electrical                 1               5   object
# 1stFlrSF                   0            1046    int64
# 2ndFlrSF                   0             599    int64
# LowQualFinSF               0              26    int64
# GrLivArea                  0            1231    int64
# BsmtFullBath               2               4  float64
# BsmtHalfBath               2               3  float64
# FullBath                   0               5    int64
# HalfBath                   0               3    int64
# BedroomAbvGr               0               7    int64
# KitchenAbvGr               0               4    int64
# KitchenQual                1               4   object
# TotRmsAbvGrd               0              12    int64
# Functional                 2               7   object
# Fireplaces                 0               5    int64
# FireplaceQu             1376               5   object
# GarageType               141               6   object
# GarageYrBlt              143             102  float64
# GarageFinish             143               3   object
# GarageCars                 1               6  float64
# GarageArea                 1             586  float64
# GarageQual               143               5   object
# GarageCond               143               5   object
# PavedDrive                 0               3   object
# WoodDeckSF                 0             363    int64
# OpenPorchSF                0             238    int64
# EnclosedPorch              0             174    int64
# 3SsnPorch                  0              28    int64
# ScreenPorch                0             111    int64
# PoolArea                   0               9    int64
# PoolQC                  2792               3   object
# Fence                   2252               4   object
# MiscFeature             2708               3   object
# MiscVal                    0              32    int64
# MoSold                     0              12    int64
# YrSold                     0               5    int64
# SaleType                   1               9   object
# SaleCondition              0               6   object

# %%
sns.distplot(df['MasVnrArea'])

# %%
df['MasVnrArea'].head(1000)
# Out:
# 0       196.0
# 1         0.0
# 2       162.0
# 3         0.0
# 4       350.0
# 5         0.0
# 6       186.0
# 7         0.0
# 8         0.0
# 9         0.0
# 
# 980       0.0
# 981       0.0
# 982     140.0
# 983       0.0
# 984       0.0
# 985       0.0
# 986     169.0
# 987       0.0
# 988     144.0
# 989       0.0
# 990     100.0
# 991     425.0
# 992       0.0
# 993       0.0
# 994       0.0
# 995       0.0
# 996      50.0
# 997       0.0
# 998       0.0
# 999     212.0
# Name: MasVnrArea, dtype: float64

# %%
scaler = MinMaxScaler((-1,1))

df['BsmtFinSF2_sc'] = scaler.fit_transform(df[['BsmtFinSF2']])
df['BsmtFinSF2_sc'].fillna(0,inplace=True)
df['LowQualFinSF_sc'] = scaler.fit_transform(df[['LowQualFinSF']])
df['WoodDeckSF_sc'] = scaler.fit_transform(df[['WoodDeckSF']])
df['OpenPorchSF_sc'] = scaler.fit_transform(df[['OpenPorchSF']])
df['EnclosedPorch_sc'] = scaler.fit_transform(df[['EnclosedPorch']])
df['3SsnPorch_sc'] = scaler.fit_transform(df[['3SsnPorch']])
df['ScreenPorch_sc'] = scaler.fit_transform(df[['ScreenPorch']])
df['MiscVal_sc'] = scaler.fit_transform(df[['MiscVal']])

df['MSZoning'].fillna('N')
df['LotFrontage'].fillna(df['LotFrontage'].median(), inplace = True)
df['Alley'].fillna('N')
df['Exterior1st'].fillna('N')
df['Exterior2nd'].fillna('N')
df['Utilities'].fillna('N')
df['MasVnrType'].fillna('N')
df['BsmtFullBath'].fillna(0)
df['BsmtHalfBath'].fillna(0)
df['FullBath'].fillna(0)
df['HalfBath'].fillna(0)
df['KitchenQual'].fillna('N')
df['Functional'].fillna('N')
df['FireplaceQu'].fillna('N')
df['GarageType'].fillna('N')
df['GarageYrBlt'].fillna(0,inplace=True)
df['GarageFinish'].fillna('N')
df['GarageCars'].fillna(0)
df['GarageArea'].fillna(0,inplace=True)
df['GarageQual'].fillna('N')
df['GarageCond'].fillna('N')
df['BsmtFinSF2'].fillna(0,inplace=True)
df['MasVnrArea'].fillna(0,inplace=True)
df['BsmtFinSF1'].fillna(0,inplace=True)
df['SaleType'].fillna('N')
df['BsmtUnfSF'].fillna(0,inplace=True)
df['TotalBsmtSF'].fillna(0,inplace=True)
df['PoolQC'].fillna('N')
df['Fence'].fillna('N')
df['MiscFeature'].fillna('N')
df['BsmtQual'].fillna('N')
df['BsmtCond'].fillna('N')
df['BsmtExposure'].fillna('N')
df['BsmtFinType1'].fillna('N')
df['BsmtFinType2'].fillna('N')
df['Electrical'].fillna('N')
df["AllSF"] = df["GrLivArea"] + df["TotalBsmtSF"]
df['Area'] = df['LotArea']*df['LotFrontage']
df['Area_log'] = np.log1p(df['Area'])

def Gar_category(cat):
    if cat <= 250:
        return 1
    elif cat <= 500 and cat > 250:
        return 2
    elif cat <= 1000 and cat > 500:
        return 3
    return 4
df['GarageArea_cat'] = df['GarageArea'].apply(Gar_category)

def Low_category(cat):
    if cat <= 1000:
        return 1
    elif cat <= 2000 and cat > 1000:
        return 2
    elif cat <= 3000 and cat > 2000:
        return 3
    return 4
df['GrLivArea_cat'] = df['GrLivArea'].apply(Low_category)

def fl1_category(cat):
    if cat <= 500:
        return 1
    elif cat <= 1000 and cat > 500:
        return 2
    elif cat <= 1500 and cat > 1000:
        return 3
    elif cat <= 2000 and cat > 1500:
        return 4
    return 5
df['1stFlrSF_cat'] = df['1stFlrSF'].apply(fl1_category)
df['2ndFlrSF_cat'] = df['2ndFlrSF'].apply(fl1_category)

def bsmtt_category(cat):
    if cat <= 500:
        return 1
    elif cat <= 1000 and cat > 500:
        return 2
    elif cat <= 1500 and cat > 1000:
        return 3
    elif cat <= 2000 and cat > 1500:
        return 4
    return 5
df['TotalBsmtSF_cat'] = df['TotalBsmtSF'].apply(bsmtt_category)

def bsmt_category(cat):
    if cat <= 500:
        return 1
    elif cat <= 1000 and cat > 500:
        return 2
    elif cat <= 1500 and cat > 1000:
        return 3
    elif cat <= 2000 and cat > 1500:
        return 4
    return 5
df['BsmtUnfSF_cat'] = df['BsmtUnfSF'].apply(bsmt_category)

def lot_category(cat):
    if cat <= 50:
        return 1
    elif cat <= 100 and cat > 50:
        return 2
    elif cat <= 150 and cat > 100:
        return 3
    return 4
df['LotFrontage_cat'] = df['LotFrontage'].apply(lot_category)

def lot_category1(cat):
    if cat <= 5000:
        return 1
    elif cat <= 10000 and cat > 5000:
        return 2
    elif cat <= 15000 and cat > 10000:
        return 3
    elif cat <= 20000 and cat > 15000:
        return 4
    elif cat <= 25000 and cat > 20000:
        return 5
    return 6
df['LotArea_cat'] = df['LotArea'].apply(lot_category1)

def year_category(yb):
    if yb <= 1910:
        return 1
    elif yb <= 1950 and yb > 1910:
        return 2
    elif yb >= 1950 and yb < 1980:
        return 3
    elif yb >= 1980 and yb < 2000:
        return 4
    return 5



df['YearBuilt_cat'] = df['YearBuilt'].apply(year_category) 
df['YearRemodAdd_cat'] = df['YearRemodAdd'].apply(year_category)
df['GarageYrBlt_cat'] = df['GarageYrBlt'].apply(year_category)

def vnr_category(cat):
    if cat <= 250:
        return 1
    elif cat <= 500 and cat > 250:
        return 2
    elif cat <= 750 and cat > 500:
        return 3
    return 4

df['MasVnrArea_cat'] = df['MasVnrArea'].apply(vnr_category)

def allsf_category(yb):
    if yb <= 1000:
        return 1
    elif yb <= 2000 and yb > 1000:
        return 2
    elif yb >= 3000 and yb < 2000:
        return 3
    elif yb >= 4000 and yb < 3000:
        return 4
    elif yb >= 5000 and yb < 4000:
        return 5
    elif yb >= 6000 and yb < 5000:
        return 6
    return 7

df['AllSF_cat'] = df['AllSF'].apply(allsf_category)


dummy_col=['YearRemodAdd', 'YearBuilt', 'AllSF_cat', 'MiscVal','OverallCond', 'OverallQual', 'BsmtFinType2', 'SaleCondition','SaleType', 'YrSold', 'MoSold', 'MiscFeature', 'Fence', 'PoolQC', 'PoolArea', 'PavedDrive', 'GarageCond', 'GarageQual', 'GarageArea_cat', 'GarageCars', 'GarageFinish', 'GarageType', 'FireplaceQu', 'Fireplaces','Functional', 'TotRmsAbvGrd', 'KitchenQual', 'KitchenAbvGr', 'BedroomAbvGr', 'HalfBath', 'FullBath', 'BsmtHalfBath', 'BsmtFullBath','GrLivArea_cat','MSSubClass', 'MSZoning', 'LotFrontage_cat', 'LotArea_cat', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
          'BldgType', 'HouseStyle', 'YearBuilt_cat', 'YearRemodAdd_cat', 'RoofStyle', 'RoofMatl', 'Exterior2nd', 'Exterior1st', 'MasVnrType', 'MasVnrArea_cat', 'ExterQual', 'ExterCond', 'Foundation', 
          'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtUnfSF_cat', 'TotalBsmtSF_cat', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF_cat', '2ndFlrSF_cat']
df = pd.get_dummies(df, columns=dummy_col, drop_first=False)

df['LotFrontage_log'] = np.log1p(df['LotFrontage'])
df['LotArea_log'] = np.log1p(df['LotArea'])
df['BsmtUnfSF_log'] = np.log1p(df['BsmtUnfSF'])

df['Is_MasVnr'] = [1 if i != 0 else 0 for i in df['MasVnrArea']]
df['Is_BsmtFinSF1'] = [1 if i != 0 else 0 for i in df['BsmtFinSF1']]
df['Is_BsmtFinSF2'] = [1 if i != 0 else 0 for i in df['BsmtFinSF2']]
df['Is_BsmtUnfSF'] = [1 if i != 0 else 0 for i in df['BsmtUnfSF']]
df['Is_TotalBsmtSF'] = [1 if i != 0 else 0 for i in df['TotalBsmtSF']]
df['Is_2ndFlrSF'] = [1 if i != 0 else 0 for i in df['2ndFlrSF']]
df['Is_LowQualFinSF'] = [1 if i != 0 else 0 for i in df['LowQualFinSF']]
df['Is_GarageArea'] = [1 if i != 0 else 0 for i in df['GarageArea']]
df['Is_WoodDeckSF'] = [1 if i != 0 else 0 for i in df['WoodDeckSF']]
df['Is_OpenPorchSF'] = [1 if i != 0 else 0 for i in df['OpenPorchSF']]
df['Is_EnclosedPorch'] = [1 if i != 0 else 0 for i in df['EnclosedPorch']]
df['Is_3SsnPorch'] = [1 if i != 0 else 0 for i in df['3SsnPorch']]
df['Is_ScreenPorch'] = [1 if i != 0 else 0 for i in df['ScreenPorch']]

# %%
# after tuning
def basic_details(df):
    b = pd.DataFrame()
    b['Missing value'] = df.isnull().sum()
    b['N unique value'] = df.nunique()
    b['dtype'] = df.dtypes
    return b
basic_details(df)
# Out:
#                        Missing value  N unique value    dtype
# LotFrontage                        0             127  float64
# LotArea                            0            1872    int64
# MasVnrArea                         0             429  float64
# BsmtFinSF1                         0             961  float64
# BsmtFinSF2                         0             248  float64
# BsmtUnfSF                          0            1111  float64
# TotalBsmtSF                        0            1026  float64
# 1stFlrSF                           0            1046    int64
# 2ndFlrSF                           0             599    int64
# LowQualFinSF                       0              26    int64
# GrLivArea                          0            1231    int64
# GarageYrBlt                        0             103  float64
# GarageArea                         0             586  float64
# WoodDeckSF                         0             363    int64
# OpenPorchSF                        0             238    int64
# EnclosedPorch                      0             174    int64
# 3SsnPorch                          0              28    int64
# ScreenPorch                        0             111    int64
# BsmtFinSF2_sc                      0             249  float64
# LowQualFinSF_sc                    0              26  float64
# WoodDeckSF_sc                      0             363  float64
# OpenPorchSF_sc                     0             238  float64
# EnclosedPorch_sc                   0             174  float64
# 3SsnPorch_sc                       0              28  float64
# ScreenPorch_sc                     0             111  float64
# MiscVal_sc                         0              32  float64
# AllSF                              0            1424  float64
# Area                               0            2114  float64
# Area_log                           0            2114  float64
# GarageYrBlt_cat                    0               5    int64
# YearRemodAdd_1950                  0               2    uint8
# YearRemodAdd_1951                  0               2    uint8
# YearRemodAdd_1952                  0               2    uint8
# YearRemodAdd_1953                  0               2    uint8
# YearRemodAdd_1954                  0               2    uint8
# YearRemodAdd_1955                  0               2    uint8
# YearRemodAdd_1956                  0               2    uint8
# YearRemodAdd_1957                  0               2    uint8
# YearRemodAdd_1958                  0               2    uint8
# YearRemodAdd_1959                  0               2    uint8
# YearRemodAdd_1960                  0               2    uint8
# YearRemodAdd_1961                  0               2    uint8
# YearRemodAdd_1962                  0               2    uint8
# YearRemodAdd_1963                  0               2    uint8
# YearRemodAdd_1964                  0               2    uint8
# YearRemodAdd_1965                  0               2    uint8
# YearRemodAdd_1966                  0               2    uint8
# YearRemodAdd_1967                  0               2    uint8
# YearRemodAdd_1968                  0               2    uint8
# YearRemodAdd_1969                  0               2    uint8
# YearRemodAdd_1970                  0               2    uint8
# YearRemodAdd_1971                  0               2    uint8
# YearRemodAdd_1972                  0               2    uint8
# YearRemodAdd_1973                  0               2    uint8
# YearRemodAdd_1974                  0               2    uint8
# YearRemodAdd_1975                  0               2    uint8
# YearRemodAdd_1976                  0               2    uint8
# YearRemodAdd_1977                  0               2    uint8
# YearRemodAdd_1978                  0               2    uint8
# YearRemodAdd_1979                  0               2    uint8
# YearRemodAdd_1980                  0               2    uint8
# YearRemodAdd_1981                  0               2    uint8
# YearRemodAdd_1982                  0               2    uint8
# YearRemodAdd_1983                  0               2    uint8
# YearRemodAdd_1984                  0               2    uint8
# YearRemodAdd_1985                  0               2    uint8
# YearRemodAdd_1986                  0               2    uint8
# YearRemodAdd_1987                  0               2    uint8
# YearRemodAdd_1988                  0               2    uint8
# YearRemodAdd_1989                  0               2    uint8
# YearRemodAdd_1990                  0               2    uint8
# YearRemodAdd_1991                  0               2    uint8
# YearRemodAdd_1992                  0               2    uint8
# YearRemodAdd_1993                  0               2    uint8
# YearRemodAdd_1994                  0               2    uint8
# YearRemodAdd_1995                  0               2    uint8
# YearRemodAdd_1996                  0               2    uint8
# YearRemodAdd_1997                  0               2    uint8
# YearRemodAdd_1998                  0               2    uint8
# YearRemodAdd_1999                  0               2    uint8
# YearRemodAdd_2000                  0               2    uint8
# YearRemodAdd_2001                  0               2    uint8
# YearRemodAdd_2002                  0               2    uint8
# YearRemodAdd_2003                  0               2    uint8
# YearRemodAdd_2004                  0               2    uint8
# YearRemodAdd_2005                  0               2    uint8
# YearRemodAdd_2006                  0               2    uint8
# YearRemodAdd_2007                  0               2    uint8
# YearRemodAdd_2008                  0               2    uint8
# YearRemodAdd_2009                  0               2    uint8
# YearRemodAdd_2010                  0               2    uint8
# YearBuilt_1879                     0               2    uint8
# YearBuilt_1880                     0               2    uint8
# YearBuilt_1882                     0               2    uint8
# YearBuilt_1885                     0               2    uint8
# YearBuilt_1890                     0               2    uint8
# YearBuilt_1895                     0               2    uint8
# YearBuilt_1896                     0               2    uint8
# YearBuilt_1898                     0               2    uint8
# YearBuilt_1900                     0               2    uint8
# YearBuilt_1901                     0               2    uint8
# YearBuilt_1902                     0               2    uint8
# YearBuilt_1904                     0               2    uint8
# YearBuilt_1905                     0               2    uint8
# YearBuilt_1906                     0               2    uint8
# YearBuilt_1907                     0               2    uint8
# YearBuilt_1908                     0               2    uint8
# YearBuilt_1910                     0               2    uint8
# YearBuilt_1911                     0               2    uint8
# YearBuilt_1912                     0               2    uint8
# YearBuilt_1913                     0               2    uint8
# YearBuilt_1914                     0               2    uint8
# YearBuilt_1915                     0               2    uint8
# YearBuilt_1916                     0               2    uint8
# YearBuilt_1917                     0               2    uint8
# YearBuilt_1918                     0               2    uint8
# YearBuilt_1919                     0               2    uint8
# YearBuilt_1920                     0               2    uint8
# YearBuilt_1921                     0               2    uint8
# YearBuilt_1922                     0               2    uint8
# YearBuilt_1923                     0               2    uint8
# YearBuilt_1924                     0               2    uint8
# YearBuilt_1925                     0               2    uint8
# YearBuilt_1926                     0               2    uint8
# YearBuilt_1927                     0               2    uint8
# YearBuilt_1928                     0               2    uint8
# YearBuilt_1929                     0               2    uint8
# YearBuilt_1930                     0               2    uint8
# YearBuilt_1931                     0               2    uint8
# YearBuilt_1932                     0               2    uint8
# YearBuilt_1934                     0               2    uint8
# YearBuilt_1935                     0               2    uint8
# YearBuilt_1936                     0               2    uint8
# YearBuilt_1937                     0               2    uint8
# YearBuilt_1938                     0               2    uint8
# YearBuilt_1939                     0               2    uint8
# YearBuilt_1940                     0               2    uint8
# YearBuilt_1941                     0               2    uint8
# YearBuilt_1942                     0               2    uint8
# YearBuilt_1945                     0               2    uint8
# YearBuilt_1946                     0               2    uint8
# YearBuilt_1947                     0               2    uint8
# YearBuilt_1948                     0               2    uint8
# YearBuilt_1949                     0               2    uint8
# YearBuilt_1950                     0               2    uint8
# YearBuilt_1951                     0               2    uint8
# YearBuilt_1952                     0               2    uint8
# YearBuilt_1953                     0               2    uint8
# YearBuilt_1954                     0               2    uint8
# YearBuilt_1955                     0               2    uint8
# YearBuilt_1956                     0               2    uint8
# YearBuilt_1957                     0               2    uint8
# YearBuilt_1958                     0               2    uint8
# YearBuilt_1959                     0               2    uint8
# YearBuilt_1960                     0               2    uint8
# YearBuilt_1961                     0               2    uint8
# YearBuilt_1962                     0               2    uint8
# YearBuilt_1963                     0               2    uint8
# YearBuilt_1964                     0               2    uint8
# YearBuilt_1965                     0               2    uint8
# YearBuilt_1966                     0               2    uint8
# YearBuilt_1967                     0               2    uint8
# YearBuilt_1968                     0               2    uint8
# YearBuilt_1969                     0               2    uint8
# YearBuilt_1970                     0               2    uint8
# YearBuilt_1971                     0               2    uint8
# YearBuilt_1972                     0               2    uint8
# YearBuilt_1973                     0               2    uint8
# YearBuilt_1974                     0               2    uint8
# YearBuilt_1975                     0               2    uint8
# YearBuilt_1976                     0               2    uint8
# YearBuilt_1977                     0               2    uint8
# YearBuilt_1978                     0               2    uint8
# YearBuilt_1979                     0               2    uint8
# YearBuilt_1980                     0               2    uint8
# YearBuilt_1981                     0               2    uint8
# YearBuilt_1982                     0               2    uint8
# YearBuilt_1983                     0               2    uint8
# YearBuilt_1984                     0               2    uint8
# YearBuilt_1985                     0               2    uint8
# YearBuilt_1986                     0               2    uint8
# YearBuilt_1987                     0               2    uint8
# YearBuilt_1988                     0               2    uint8
# YearBuilt_1989                     0               2    uint8
# YearBuilt_1990                     0               2    uint8
# YearBuilt_1991                     0               2    uint8
# YearBuilt_1992                     0               2    uint8
# YearBuilt_1993                     0               2    uint8
# YearBuilt_1994                     0               2    uint8
# YearBuilt_1995                     0               2    uint8
# YearBuilt_1996                     0               2    uint8
# YearBuilt_1997                     0               2    uint8
# YearBuilt_1998                     0               2    uint8
# YearBuilt_1999                     0               2    uint8
# YearBuilt_2000                     0               2    uint8
# YearBuilt_2001                     0               2    uint8
# YearBuilt_2002                     0               2    uint8
# YearBuilt_2003                     0               2    uint8
# YearBuilt_2004                     0               2    uint8
# YearBuilt_2005                     0               2    uint8
# YearBuilt_2006                     0               2    uint8
# YearBuilt_2007                     0               2    uint8
# YearBuilt_2008                     0               2    uint8
# YearBuilt_2009                     0               2    uint8
# YearBuilt_2010                     0               2    uint8
# AllSF_cat_1                        0               2    uint8
# AllSF_cat_2                        0               2    uint8
# AllSF_cat_7                        0               2    uint8
# MiscVal_0                          0               2    uint8
# MiscVal_54                         0               2    uint8
# MiscVal_80                         0               2    uint8
# MiscVal_300                        0               2    uint8
# MiscVal_400                        0               2    uint8
# MiscVal_420                        0               2    uint8
# MiscVal_450                        0               2    uint8
# MiscVal_455                        0               2    uint8
# MiscVal_460                        0               2    uint8
# MiscVal_480                        0               2    uint8
# MiscVal_490                        0               2    uint8
# MiscVal_500                        0               2    uint8
# MiscVal_600                        0               2    uint8
# MiscVal_650                        0               2    uint8
# MiscVal_700                        0               2    uint8
# MiscVal_750                        0               2    uint8
# MiscVal_800                        0               2    uint8
# MiscVal_900                        0               2    uint8
# MiscVal_1000                       0               2    uint8
# MiscVal_1200                       0               2    uint8
# MiscVal_1300                       0               2    uint8
# MiscVal_1400                       0               2    uint8
# MiscVal_1500                       0               2    uint8
# MiscVal_1512                       0               2    uint8
# MiscVal_2000                       0               2    uint8
# MiscVal_2500                       0               2    uint8
# MiscVal_3000                       0               2    uint8
# MiscVal_4500                       0               2    uint8
# MiscVal_6500                       0               2    uint8
# MiscVal_12500                      0               2    uint8
# MiscVal_15500                      0               2    uint8
# MiscVal_17000                      0               2    uint8
# OverallCond_1                      0               2    uint8
# OverallCond_2                      0               2    uint8
# OverallCond_3                      0               2    uint8
# OverallCond_4                      0               2    uint8
# OverallCond_5                      0               2    uint8
# OverallCond_6                      0               2    uint8
# OverallCond_7                      0               2    uint8
# OverallCond_8                      0               2    uint8
# OverallCond_9                      0               2    uint8
# OverallQual_1                      0               2    uint8
# OverallQual_2                      0               2    uint8
# OverallQual_3                      0               2    uint8
# OverallQual_4                      0               2    uint8
# OverallQual_5                      0               2    uint8
# OverallQual_6                      0               2    uint8
# OverallQual_7                      0               2    uint8
# OverallQual_8                      0               2    uint8
# OverallQual_9                      0               2    uint8
# OverallQual_10                     0               2    uint8
# BsmtFinType2_ALQ                   0               2    uint8
# BsmtFinType2_BLQ                   0               2    uint8
# BsmtFinType2_GLQ                   0               2    uint8
# BsmtFinType2_LwQ                   0               2    uint8
# BsmtFinType2_Rec                   0               2    uint8
# BsmtFinType2_Unf                   0               2    uint8
# SaleCondition_Abnorml              0               2    uint8
# SaleCondition_AdjLand              0               2    uint8
# SaleCondition_Alloca               0               2    uint8
# SaleCondition_Family               0               2    uint8
# SaleCondition_Normal               0               2    uint8
# SaleCondition_Partial              0               2    uint8
# SaleType_COD                       0               2    uint8
# SaleType_CWD                       0               2    uint8
# SaleType_Con                       0               2    uint8
# SaleType_ConLD                     0               2    uint8
# SaleType_ConLI                     0               2    uint8
# SaleType_ConLw                     0               2    uint8
# SaleType_New                       0               2    uint8
# SaleType_Oth                       0               2    uint8
# SaleType_WD                        0               2    uint8
# YrSold_2006                        0               2    uint8
# YrSold_2007                        0               2    uint8
# YrSold_2008                        0               2    uint8
# YrSold_2009                        0               2    uint8
# YrSold_2010                        0               2    uint8
# MoSold_1                           0               2    uint8
# MoSold_2                           0               2    uint8
# MoSold_3                           0               2    uint8
# MoSold_4                           0               2    uint8
# MoSold_5                           0               2    uint8
# MoSold_6                           0               2    uint8
# MoSold_7                           0               2    uint8
# MoSold_8                           0               2    uint8
# MoSold_9                           0               2    uint8
# MoSold_10                          0               2    uint8
# MoSold_11                          0               2    uint8
# MoSold_12                          0               2    uint8
# MiscFeature_Gar2                   0               2    uint8
# MiscFeature_Othr                   0               2    uint8
# MiscFeature_Shed                   0               2    uint8
# Fence_GdPrv                        0               2    uint8
# Fence_GdWo                         0               2    uint8
# Fence_MnPrv                        0               2    uint8
# Fence_MnWw                         0               2    uint8
# PoolQC_Ex                          0               2    uint8
# PoolQC_Fa                          0               2    uint8
# PoolQC_Gd                          0               2    uint8
# PoolArea_0                         0               2    uint8
# PoolArea_144                       0               2    uint8
# PoolArea_228                       0               2    uint8
# PoolArea_368                       0               2    uint8
# PoolArea_444                       0               2    uint8
# PoolArea_561                       0               2    uint8
# PoolArea_576                       0               2    uint8
# PoolArea_648                       0               2    uint8
# PoolArea_800                       0               2    uint8
# PavedDrive_N                       0               2    uint8
# PavedDrive_P                       0               2    uint8
# PavedDrive_Y                       0               2    uint8
# GarageCond_Ex                      0               2    uint8
# GarageCond_Fa                      0               2    uint8
# GarageCond_Gd                      0               2    uint8
# GarageCond_Po                      0               2    uint8
# GarageCond_TA                      0               2    uint8
# GarageQual_Ex                      0               2    uint8
# GarageQual_Fa                      0               2    uint8
# GarageQual_Gd                      0               2    uint8
# GarageQual_Po                      0               2    uint8
# GarageQual_TA                      0               2    uint8
# GarageArea_cat_1                   0               2    uint8
# GarageArea_cat_2                   0               2    uint8
# GarageArea_cat_3                   0               2    uint8
# GarageArea_cat_4                   0               2    uint8
# GarageCars_0.0                     0               2    uint8
# GarageCars_1.0                     0               2    uint8
# GarageCars_2.0                     0               2    uint8
# GarageCars_3.0                     0               2    uint8
# GarageCars_4.0                     0               2    uint8
# GarageCars_5.0                     0               2    uint8
# GarageFinish_Fin                   0               2    uint8
# GarageFinish_RFn                   0               2    uint8
# GarageFinish_Unf                   0               2    uint8
# GarageType_2Types                  0               2    uint8
# GarageType_Attchd                  0               2    uint8
# GarageType_Basment                 0               2    uint8
# GarageType_BuiltIn                 0               2    uint8
# GarageType_CarPort                 0               2    uint8
# GarageType_Detchd                  0               2    uint8
# FireplaceQu_Ex                     0               2    uint8
# FireplaceQu_Fa                     0               2    uint8
# FireplaceQu_Gd                     0               2    uint8
# FireplaceQu_Po                     0               2    uint8
# FireplaceQu_TA                     0               2    uint8
# Fireplaces_0                       0               2    uint8
# Fireplaces_1                       0               2    uint8
# Fireplaces_2                       0               2    uint8
# Fireplaces_3                       0               2    uint8
# Fireplaces_4                       0               2    uint8
# Functional_Maj1                    0               2    uint8
# Functional_Maj2                    0               2    uint8
# Functional_Min1                    0               2    uint8
# Functional_Min2                    0               2    uint8
# Functional_Mod                     0               2    uint8
# Functional_Sev                     0               2    uint8
# Functional_Typ                     0               2    uint8
# TotRmsAbvGrd_3                     0               2    uint8
# TotRmsAbvGrd_4                     0               2    uint8
# TotRmsAbvGrd_5                     0               2    uint8
# TotRmsAbvGrd_6                     0               2    uint8
# TotRmsAbvGrd_7                     0               2    uint8
# TotRmsAbvGrd_8                     0               2    uint8
# TotRmsAbvGrd_9                     0               2    uint8
# TotRmsAbvGrd_10                    0               2    uint8
# TotRmsAbvGrd_11                    0               2    uint8
# TotRmsAbvGrd_12                    0               2    uint8
# TotRmsAbvGrd_13                    0               2    uint8
# TotRmsAbvGrd_15                    0               2    uint8
# KitchenQual_Ex                     0               2    uint8
# KitchenQual_Fa                     0               2    uint8
# KitchenQual_Gd                     0               2    uint8
# KitchenQual_TA                     0               2    uint8
# KitchenAbvGr_0                     0               2    uint8
# KitchenAbvGr_1                     0               2    uint8
# KitchenAbvGr_2                     0               2    uint8
# KitchenAbvGr_3                     0               2    uint8
# BedroomAbvGr_0                     0               2    uint8
# BedroomAbvGr_1                     0               2    uint8
# BedroomAbvGr_2                     0               2    uint8
# BedroomAbvGr_3                     0               2    uint8
# BedroomAbvGr_4                     0               2    uint8
# BedroomAbvGr_5                     0               2    uint8
# BedroomAbvGr_6                     0               2    uint8
# HalfBath_0                         0               2    uint8
# HalfBath_1                         0               2    uint8
# HalfBath_2                         0               2    uint8
# FullBath_0                         0               2    uint8
# FullBath_1                         0               2    uint8
# FullBath_2                         0               2    uint8
# FullBath_3                         0               2    uint8
# FullBath_4                         0               2    uint8
# BsmtHalfBath_0.0                   0               2    uint8
# BsmtHalfBath_1.0                   0               2    uint8
# BsmtHalfBath_2.0                   0               2    uint8
# BsmtFullBath_0.0                   0               2    uint8
# BsmtFullBath_1.0                   0               2    uint8
# BsmtFullBath_2.0                   0               2    uint8
# BsmtFullBath_3.0                   0               2    uint8
# GrLivArea_cat_1                    0               2    uint8
# GrLivArea_cat_2                    0               2    uint8
# GrLivArea_cat_3                    0               2    uint8
# GrLivArea_cat_4                    0               2    uint8
# MSSubClass_20                      0               2    uint8
# MSSubClass_30                      0               2    uint8
# MSSubClass_40                      0               2    uint8
# MSSubClass_45                      0               2    uint8
# MSSubClass_50                      0               2    uint8
# MSSubClass_60                      0               2    uint8
# MSSubClass_70                      0               2    uint8
# MSSubClass_75                      0               2    uint8
# MSSubClass_80                      0               2    uint8
# MSSubClass_85                      0               2    uint8
# MSSubClass_90                      0               2    uint8
# MSSubClass_120                     0               2    uint8
# MSSubClass_150                     0               2    uint8
# MSSubClass_160                     0               2    uint8
# MSSubClass_180                     0               2    uint8
# MSSubClass_190                     0               2    uint8
# MSZoning_C (all)                   0               2    uint8
# MSZoning_FV                        0               2    uint8
# MSZoning_RH                        0               2    uint8
# MSZoning_RL                        0               2    uint8
# MSZoning_RM                        0               2    uint8
# LotFrontage_cat_1                  0               2    uint8
# LotFrontage_cat_2                  0               2    uint8
# LotFrontage_cat_3                  0               2    uint8
# LotFrontage_cat_4                  0               2    uint8
# LotArea_cat_1                      0               2    uint8
# LotArea_cat_2                      0               2    uint8
# LotArea_cat_3                      0               2    uint8
# LotArea_cat_4                      0               2    uint8
# LotArea_cat_5                      0               2    uint8
# LotArea_cat_6                      0               2    uint8
# Street_Grvl                        0               2    uint8
# Street_Pave                        0               2    uint8
# Alley_Grvl                         0               2    uint8
# Alley_Pave                         0               2    uint8
# LotShape_IR1                       0               2    uint8
# LotShape_IR2                       0               2    uint8
# LotShape_IR3                       0               2    uint8
# LotShape_Reg                       0               2    uint8
# LandContour_Bnk                    0               2    uint8
# LandContour_HLS                    0               2    uint8
# LandContour_Low                    0               2    uint8
# LandContour_Lvl                    0               2    uint8
# Utilities_AllPub                   0               2    uint8
# LotConfig_Corner                   0               2    uint8
# LotConfig_CulDSac                  0               2    uint8
# LotConfig_FR2                      0               2    uint8
# LotConfig_FR3                      0               2    uint8
# LotConfig_Inside                   0               2    uint8
# LandSlope_Gtl                      0               2    uint8
# LandSlope_Mod                      0               2    uint8
# LandSlope_Sev                      0               2    uint8
# Neighborhood_Blmngtn               0               2    uint8
# Neighborhood_Blueste               0               2    uint8
# Neighborhood_BrDale                0               2    uint8
# Neighborhood_BrkSide               0               2    uint8
# Neighborhood_ClearCr               0               2    uint8
# Neighborhood_CollgCr               0               2    uint8
# Neighborhood_Crawfor               0               2    uint8
# Neighborhood_Edwards               0               2    uint8
# Neighborhood_Gilbert               0               2    uint8
# Neighborhood_IDOTRR                0               2    uint8
# Neighborhood_MeadowV               0               2    uint8
# Neighborhood_Mitchel               0               2    uint8
# Neighborhood_NAmes                 0               2    uint8
# Neighborhood_NPkVill               0               2    uint8
# Neighborhood_NWAmes                0               2    uint8
# Neighborhood_NoRidge               0               2    uint8
# Neighborhood_NridgHt               0               2    uint8
# Neighborhood_OldTown               0               2    uint8
# Neighborhood_SWISU                 0               2    uint8
# Neighborhood_Sawyer                0               2    uint8
# Neighborhood_SawyerW               0               2    uint8
# Neighborhood_Somerst               0               2    uint8
# Neighborhood_StoneBr               0               2    uint8
# Neighborhood_Timber                0               2    uint8
# Neighborhood_Veenker               0               2    uint8
# Condition1_Artery                  0               2    uint8
# Condition1_Feedr                   0               2    uint8
# Condition1_Norm                    0               2    uint8
# Condition1_PosA                    0               2    uint8
# Condition1_PosN                    0               2    uint8
# Condition1_RRAe                    0               2    uint8
# Condition1_RRAn                    0               2    uint8
# Condition1_RRNe                    0               2    uint8
# Condition1_RRNn                    0               2    uint8
# Condition2_Artery                  0               2    uint8
# Condition2_Feedr                   0               2    uint8
# Condition2_Norm                    0               2    uint8
# Condition2_PosA                    0               2    uint8
# Condition2_PosN                    0               2    uint8
# Condition2_RRAn                    0               2    uint8
# Condition2_RRNn                    0               2    uint8
# BldgType_1Fam                      0               2    uint8
# BldgType_2fmCon                    0               2    uint8
# BldgType_Duplex                    0               2    uint8
# BldgType_Twnhs                     0               2    uint8
# BldgType_TwnhsE                    0               2    uint8
# HouseStyle_1.5Fin                  0               2    uint8
# HouseStyle_1.5Unf                  0               2    uint8
# HouseStyle_1Story                  0               2    uint8
# HouseStyle_2.5Fin                  0               2    uint8
# HouseStyle_2.5Unf                  0               2    uint8
# HouseStyle_2Story                  0               2    uint8
# HouseStyle_SFoyer                  0               2    uint8
# HouseStyle_SLvl                    0               2    uint8
# YearBuilt_cat_1                    0               2    uint8
# YearBuilt_cat_2                    0               2    uint8
# YearBuilt_cat_3                    0               2    uint8
# YearBuilt_cat_4                    0               2    uint8
# YearBuilt_cat_5                    0               2    uint8
# YearRemodAdd_cat_2                 0               2    uint8
# YearRemodAdd_cat_3                 0               2    uint8
# YearRemodAdd_cat_4                 0               2    uint8
# YearRemodAdd_cat_5                 0               2    uint8
# RoofStyle_Flat                     0               2    uint8
# RoofStyle_Gable                    0               2    uint8
# RoofStyle_Gambrel                  0               2    uint8
# RoofStyle_Hip                      0               2    uint8
# RoofStyle_Mansard                  0               2    uint8
# RoofStyle_Shed                     0               2    uint8
# RoofMatl_CompShg                   0               2    uint8
# RoofMatl_Membran                   0               2    uint8
# RoofMatl_Metal                     0               2    uint8
# RoofMatl_Roll                      0               2    uint8
# RoofMatl_Tar&Grv                   0               2    uint8
# RoofMatl_WdShake                   0               2    uint8
# RoofMatl_WdShngl                   0               2    uint8
# Exterior2nd_AsbShng                0               2    uint8
# Exterior2nd_AsphShn                0               2    uint8
# Exterior2nd_Brk Cmn                0               2    uint8
# Exterior2nd_BrkFace                0               2    uint8
# Exterior2nd_CBlock                 0               2    uint8
# Exterior2nd_CmentBd                0               2    uint8
# Exterior2nd_HdBoard                0               2    uint8
# Exterior2nd_ImStucc                0               2    uint8
# Exterior2nd_MetalSd                0               2    uint8
# Exterior2nd_Other                  0               2    uint8
# Exterior2nd_Plywood                0               2    uint8
# Exterior2nd_Stone                  0               2    uint8
# Exterior2nd_Stucco                 0               2    uint8
# Exterior2nd_VinylSd                0               2    uint8
# Exterior2nd_Wd Sdng                0               2    uint8
# Exterior2nd_Wd Shng                0               2    uint8
# Exterior1st_AsbShng                0               2    uint8
# Exterior1st_AsphShn                0               2    uint8
# Exterior1st_BrkComm                0               2    uint8
# Exterior1st_BrkFace                0               2    uint8
# Exterior1st_CBlock                 0               2    uint8
# Exterior1st_CemntBd                0               2    uint8
# Exterior1st_HdBoard                0               2    uint8
# Exterior1st_ImStucc                0               2    uint8
# Exterior1st_MetalSd                0               2    uint8
# Exterior1st_Plywood                0               2    uint8
# Exterior1st_Stone                  0               2    uint8
# Exterior1st_Stucco                 0               2    uint8
# Exterior1st_VinylSd                0               2    uint8
# Exterior1st_Wd Sdng                0               2    uint8
# Exterior1st_WdShing                0               2    uint8
# MasVnrType_BrkCmn                  0               2    uint8
# MasVnrType_BrkFace                 0               2    uint8
# MasVnrType_None                    0               2    uint8
# MasVnrType_Stone                   0               2    uint8
# MasVnrArea_cat_1                   0               2    uint8
# MasVnrArea_cat_2                   0               2    uint8
# MasVnrArea_cat_3                   0               2    uint8
# MasVnrArea_cat_4                   0               2    uint8
# ExterQual_Ex                       0               2    uint8
# ExterQual_Fa                       0               2    uint8
# ExterQual_Gd                       0               2    uint8
# ExterQual_TA                       0               2    uint8
# ExterCond_Ex                       0               2    uint8
# ExterCond_Fa                       0               2    uint8
# ExterCond_Gd                       0               2    uint8
# ExterCond_Po                       0               2    uint8
# ExterCond_TA                       0               2    uint8
# Foundation_BrkTil                  0               2    uint8
# Foundation_CBlock                  0               2    uint8
# Foundation_PConc                   0               2    uint8
# Foundation_Slab                    0               2    uint8
# Foundation_Stone                   0               2    uint8
# Foundation_Wood                    0               2    uint8
# BsmtQual_Ex                        0               2    uint8
# BsmtQual_Fa                        0               2    uint8
# BsmtQual_Gd                        0               2    uint8
# BsmtQual_TA                        0               2    uint8
# BsmtCond_Fa                        0               2    uint8
# BsmtCond_Gd                        0               2    uint8
# BsmtCond_Po                        0               2    uint8
# BsmtCond_TA                        0               2    uint8
# BsmtExposure_Av                    0               2    uint8
# BsmtExposure_Gd                    0               2    uint8
# BsmtExposure_Mn                    0               2    uint8
# BsmtExposure_No                    0               2    uint8
# BsmtFinType1_ALQ                   0               2    uint8
# BsmtFinType1_BLQ                   0               2    uint8
# BsmtFinType1_GLQ                   0               2    uint8
# BsmtFinType1_LwQ                   0               2    uint8
# BsmtFinType1_Rec                   0               2    uint8
# BsmtFinType1_Unf                   0               2    uint8
# BsmtUnfSF_cat_1                    0               2    uint8
# BsmtUnfSF_cat_2                    0               2    uint8
# BsmtUnfSF_cat_3                    0               2    uint8
# BsmtUnfSF_cat_4                    0               2    uint8
# BsmtUnfSF_cat_5                    0               2    uint8
# TotalBsmtSF_cat_1                  0               2    uint8
# TotalBsmtSF_cat_2                  0               2    uint8
# TotalBsmtSF_cat_3                  0               2    uint8
# TotalBsmtSF_cat_4                  0               2    uint8
# TotalBsmtSF_cat_5                  0               2    uint8
# Heating_Floor                      0               2    uint8
# Heating_GasA                       0               2    uint8
# Heating_GasW                       0               2    uint8
# Heating_Grav                       0               2    uint8
# Heating_OthW                       0               2    uint8
# Heating_Wall                       0               2    uint8
# HeatingQC_Ex                       0               2    uint8
# HeatingQC_Fa                       0               2    uint8
# HeatingQC_Gd                       0               2    uint8
# HeatingQC_Po                       0               2    uint8
# HeatingQC_TA                       0               2    uint8
# CentralAir_N                       0               2    uint8
# CentralAir_Y                       0               2    uint8
# Electrical_FuseA                   0               2    uint8
# Electrical_FuseF                   0               2    uint8
# Electrical_FuseP                   0               2    uint8
# Electrical_Mix                     0               2    uint8
# Electrical_SBrkr                   0               2    uint8
# 1stFlrSF_cat_1                     0               2    uint8
# 1stFlrSF_cat_2                     0               2    uint8
# 1stFlrSF_cat_3                     0               2    uint8
# 1stFlrSF_cat_4                     0               2    uint8
# 1stFlrSF_cat_5                     0               2    uint8
# 2ndFlrSF_cat_1                     0               2    uint8
# 2ndFlrSF_cat_2                     0               2    uint8
# 2ndFlrSF_cat_3                     0               2    uint8
# 2ndFlrSF_cat_4                     0               2    uint8
# LotFrontage_log                    0             127  float64
# LotArea_log                        0            1872  float64
# BsmtUnfSF_log                      0            1111  float64
# Is_MasVnr                          0               2    int64
# Is_BsmtFinSF1                      0               2    int64
# Is_BsmtFinSF2                      0               2    int64
# Is_BsmtUnfSF                       0               2    int64
# Is_TotalBsmtSF                     0               2    int64
# Is_2ndFlrSF                        0               2    int64
# Is_LowQualFinSF                    0               2    int64
# Is_GarageArea                      0               2    int64
# Is_WoodDeckSF                      0               2    int64
# Is_OpenPorchSF                     0               2    int64
# Is_EnclosedPorch                   0               2    int64
# Is_3SsnPorch                       0               2    int64
# Is_ScreenPorch                     0               2    int64

# %%
df.shape
# Out:
# (2797, 664)

# %%
def descrictive_stat_feat(df):
    df = pd.DataFrame(df)
    dcol= [c for c in df.columns if df[c].nunique()>=10]
    d_median = df[dcol].median(axis=0)
    d_mean = df[dcol].mean(axis=0)
    q1 = df[dcol].apply(np.float32).quantile(0.25)
    q3 = df[dcol].apply(np.float32).quantile(0.75)
    
    #Add mean and median column to data set having more then 10 categories
    for c in dcol:
        df[c+str('_median_range')] = (df[c].astype(np.float32).values > d_median[c]).astype(np.int8)
        df[c+str('_mean_range')] = (df[c].astype(np.float32).values > d_mean[c]).astype(np.int8)
        df[c+str('_q1')] = (df[c].astype(np.float32).values < q1[c]).astype(np.int8)
        df[c+str('_q3')] = (df[c].astype(np.float32).values > q3[c]).astype(np.int8)
    return df

df = descrictive_stat_feat(df)

# %%
df.shape
# Out:
# (2797, 792)

# %%
tot_cat_col = list(df.select_dtypes(include=['category']).columns)
num_col = [c for c in df.columns if c not in tot_cat_col]

# %%
def outlier(df,columns):
    for i in columns:
        quartile_1,quartile_3 = np.percentile(df[i],[25,75])
        quartile_f,quartile_l = np.percentile(df[i],[1,99])
        IQR = quartile_3-quartile_1
        lower_bound = quartile_1 - (1.5*IQR)
        upper_bound = quartile_3 + (1.5*IQR)
        print(i,lower_bound,upper_bound,quartile_f,quartile_l)
                
        df[i].loc[df[i] < lower_bound] = quartile_f
        df[i].loc[df[i] > upper_bound] = quartile_l
        
outlier(df,num_col)
# Out:
# LotFrontage 33.0 105.0 21.0 130.0
# LotArea 1441.5 17397.5 1680.0 25508.51999999998
# MasVnrArea -243.0 405.0 0.0 738.6399999999994
# GarageFinish_RFn -1.5 2.5 0.0 1.0
# GarageFinish_Unf -1.5 2.5 0.0 1.0
# GarageType_2Types 0.0 0.0 0.0 0.0
# GarageType_Attchd -1.5 2.5 0.0 1.0
# GarageType_Basment 0.0 0.0 0.0 1.0
# GarageType_BuiltIn 0.0 0.0 0.0 1.0
# GarageType_CarPort 0.0 0.0 0.0 0.0
# GarageType_Detchd -1.5 2.5 0.0 1.0
# FireplaceQu_Ex 0.0 0.0 0.0 1.0
# FireplaceQu_Fa 0.0 0.0 0.0 1.0
# FireplaceQu_Gd -1.5 2.5 0.0 1.0
# FireplaceQu_Po 0.0 0.0 0.0 1.0
# FireplaceQu_TA 0.0 0.0 0.0 1.0
# Fireplaces_0 -1.5 2.5 0.0 1.0
# Fireplaces_1 -1.5 2.5 0.0 1.0
# Fireplaces_2 0.0 0.0 0.0 1.0
# Fireplaces_3 0.0 0.0 0.0 0.0
# Fireplaces_4 0.0 0.0 0.0 0.0
# Functional_Maj1 0.0 0.0 0.0 0.0
# Functional_Maj2 0.0 0.0 0.0 0.0
# Functional_Min1 0.0 0.0 0.0 1.0
# Functional_Min2 0.0 0.0 0.0 1.0
# Functional_Mod 0.0 0.0 0.0 1.0
# Functional_Sev 0.0 0.0 0.0 0.0
# Functional_Typ 1.0 1.0 0.0 1.0
# TotRmsAbvGrd_3 0.0 0.0 0.0 0.0
# TotRmsAbvGrd_4 0.0 0.0 0.0 1.0
# TotRmsAbvGrd_5 0.0 0.0 0.0 1.0
# TotRmsAbvGrd_6 -1.5 2.5 0.0 1.0
# TotRmsAbvGrd_7 0.0 0.0 0.0 1.0
# TotRmsAbvGrd_8 0.0 0.0 0.0 1.0
# TotRmsAbvGrd_9 0.0 0.0 0.0 1.0
# TotRmsAbvGrd_10 0.0 0.0 0.0 1.0
# TotRmsAbvGrd_11 0.0 0.0 0.0 0.0
# TotRmsAbvGrd_12 0.0 0.0 0.0 0.0
# TotRmsAbvGrd_13 0.0 0.0 0.0 0.0
# TotRmsAbvGrd_15 0.0 0.0 0.0 0.0
# KitchenQual_Ex 0.0 0.0 0.0 1.0
# KitchenQual_Fa 0.0 0.0 0.0 1.0
# KitchenQual_Gd -1.5 2.5 0.0 1.0
# KitchenQual_TA -1.5 2.5 0.0 1.0
# KitchenAbvGr_0 0.0 0.0 0.0 0.0
# KitchenAbvGr_1 1.0 1.0 0.0 1.0
# KitchenAbvGr_2 0.0 0.0 0.0 1.0
# KitchenAbvGr_3 0.0 0.0 0.0 0.0
# BedroomAbvGr_0 0.0 0.0 0.0 0.0
# BedroomAbvGr_1 0.0 0.0 0.0 1.0
# BedroomAbvGr_2 -1.5 2.5 0.0 1.0
# BedroomAbvGr_3 -1.5 2.5 0.0 1.0
# BedroomAbvGr_4 0.0 0.0 0.0 1.0
# BedroomAbvGr_5 0.0 0.0 0.0 1.0
# BedroomAbvGr_6 0.0 0.0 0.0 0.0
# HalfBath_0 -1.5 2.5 0.0 1.0
# HalfBath_1 -1.5 2.5 0.0 1.0
# HalfBath_2 0.0 0.0 0.0 0.0
# FullBath_0 0.0 0.0 0.0 0.0
# FullBath_1 -1.5 2.5 0.0 1.0
# FullBath_2 -1.5 2.5 0.0 1.0
# FullBath_3 0.0 0.0 0.0 1.0
# FullBath_4 0.0 0.0 0.0 0.0
# LotConfig_FR2 0.0 0.0 0.0 1.0
# LotConfig_FR3 0.0 0.0 0.0 0.0
# LotConfig_Inside -1.5 2.5 0.0 1.0
# LandSlope_Gtl 1.0 1.0 0.0 1.0
# LandSlope_Mod 0.0 0.0 0.0 1.0
# LandSlope_Sev 0.0 0.0 0.0 0.0
# Neighborhood_Blmngtn 0.0 0.0 0.0 0.03999999999996362
# Neighborhood_Blueste 0.0 0.0 0.0 0.0
# Neighborhood_BrDale 0.0 0.0 0.0 1.0
# Neighborhood_BrkSide 0.0 0.0 0.0 1.0
# Neighborhood_ClearCr 0.0 0.0 0.0 1.0
# Neighborhood_CollgCr 0.0 0.0 0.0 1.0
# Neighborhood_Crawfor 0.0 0.0 0.0 1.0
# Neighborhood_Edwards 0.0 0.0 0.0 1.0
# Neighborhood_Gilbert 0.0 0.0 0.0 1.0
# Neighborhood_IDOTRR 0.0 0.0 0.0 1.0
# Neighborhood_MeadowV 0.0 0.0 0.0 1.0
# Neighborhood_Mitchel 0.0 0.0 0.0 1.0
# Neighborhood_NAmes 0.0 0.0 0.0 1.0
# Neighborhood_NPkVill 0.0 0.0 0.0 0.0
# Neighborhood_NWAmes 0.0 0.0 0.0 1.0
# Neighborhood_NoRidge 0.0 0.0 0.0 1.0
# Neighborhood_NridgHt 0.0 0.0 0.0 1.0
# Neighborhood_OldTown 0.0 0.0 0.0 1.0
# Neighborhood_SWISU 0.0 0.0 0.0 1.0
# Neighborhood_Sawyer 0.0 0.0 0.0 1.0
# Neighborhood_SawyerW 0.0 0.0 0.0 1.0
# Neighborhood_Somerst 0.0 0.0 0.0 1.0
# Neighborhood_StoneBr 0.0 0.0 0.0 1.0
# Neighborhood_Timber 0.0 0.0 0.0 1.0
# Neighborhood_Veenker 0.0 0.0 0.0 0.0
# Condition1_Artery 0.0 0.0 0.0 1.0
# Condition1_Feedr 0.0 0.0 0.0 1.0
# Condition1_Norm 1.0 1.0 0.0 1.0
# Condition1_PosA 0.0 0.0 0.0 0.0
# Condition1_PosN 0.0 0.0 0.0 1.0
# Condition1_RRAe 0.0 0.0 0.0 0.03999999999996362
# Condition1_RRAn 0.0 0.0 0.0 1.0
# Condition1_RRNe 0.0 0.0 0.0 0.0
# Condition1_RRNn 0.0 0.0 0.0 0.0
# Condition2_Artery 0.0 0.0 0.0 0.0
# Condition2_Feedr 0.0 0.0 0.0 0.0
# Condition2_Norm 1.0 1.0 1.0 1.0
# Condition2_PosA 0.0 0.0 0.0 0.0
# Condition2_PosN 0.0 0.0 0.0 0.0
# Condition2_RRAn 0.0 0.0 0.0 0.0
# Condition2_RRNn 0.0 0.0 0.0 0.0
# BldgType_1Fam 1.0 1.0 0.0 1.0
# BldgType_2fmCon 0.0 0.0 0.0 1.0
# BldgType_Duplex 0.0 0.0 0.0 1.0
# BldgType_Twnhs 0.0 0.0 0.0 1.0
# BldgType_TwnhsE 0.0 0.0 0.0 1.0
# HouseStyle_1.5Fin 0.0 0.0 0.0 1.0
# HouseStyle_1.5Unf 0.0 0.0 0.0 0.0
# Exterior1st_MetalSd 0.0 0.0 0.0 1.0
# Exterior1st_Plywood 0.0 0.0 0.0 1.0
# Exterior1st_Stone 0.0 0.0 0.0 0.0
# Exterior1st_Stucco 0.0 0.0 0.0 1.0
# Exterior1st_VinylSd -1.5 2.5 0.0 1.0
# Exterior1st_Wd Sdng 0.0 0.0 0.0 1.0
# Exterior1st_WdShing 0.0 0.0 0.0 1.0
# MasVnrType_BrkCmn 0.0 0.0 0.0 0.0
# MasVnrType_BrkFace -1.5 2.5 0.0 1.0
# MasVnrType_None -1.5 2.5 0.0 1.0
# MasVnrType_Stone 0.0 0.0 0.0 1.0
# MasVnrArea_cat_1 1.0 1.0 0.0 1.0
# MasVnrArea_cat_2 0.0 0.0 0.0 1.0
# MasVnrArea_cat_3 0.0 0.0 0.0 1.0
# MasVnrArea_cat_4 0.0 0.0 0.0 0.03999999999996362
# ExterQual_Ex 0.0 0.0 0.0 1.0
# ExterQual_Fa 0.0 0.0 0.0 1.0
# ExterQual_Gd -1.5 2.5 0.0 1.0
# ExterQual_TA -1.5 2.5 0.0 1.0
# ExterCond_Ex 0.0 0.0 0.0 0.0
# ExterCond_Fa 0.0 0.0 0.0 1.0
# ExterCond_Gd 0.0 0.0 0.0 1.0
# ExterCond_Po 0.0 0.0 0.0 0.0
# ExterCond_TA 1.0 1.0 0.0 1.0
# Foundation_BrkTil 0.0 0.0 0.0 1.0
# Foundation_CBlock -1.5 2.5 0.0 1.0
# Foundation_PConc -1.5 2.5 0.0 1.0
# Foundation_Slab 0.0 0.0 0.0 1.0
# Foundation_Stone 0.0 0.0 0.0 0.0
# Foundation_Wood 0.0 0.0 0.0 0.0
# BsmtQual_Ex 0.0 0.0 0.0 1.0
# BsmtQual_Fa 0.0 0.0 0.0 1.0
# BsmtQual_Gd -1.5 2.5 0.0 1.0
# BsmtQual_TA -1.5 2.5 0.0 1.0
# BsmtCond_Fa 0.0 0.0 0.0 1.0
# BsmtCond_Gd 0.0 0.0 0.0 1.0
# BsmtCond_Po 0.0 0.0 0.0 0.0
# BsmtCond_TA 1.0 1.0 0.0 1.0
# BsmtExposure_Av 0.0 0.0 0.0 1.0
# BsmtExposure_Gd 0.0 0.0 0.0 1.0
# BsmtExposure_Mn 0.0 0.0 0.0 1.0
# BsmtExposure_No -1.5 2.5 0.0 1.0
# BsmtFinType1_ALQ 0.0 0.0 0.0 1.0
# BsmtFinType1_BLQ 0.0 0.0 0.0 1.0
# BsmtFinType1_GLQ -1.5 2.5 0.0 1.0
# BsmtFinType1_LwQ 0.0 0.0 0.0 1.0
# BsmtFinType1_Rec 0.0 0.0 0.0 1.0
# BsmtFinType1_Unf -1.5 2.5 0.0 1.0
# BsmtUnfSF_cat_1 -1.5 2.5 0.0 1.0
# BsmtUnfSF_cat_2 -1.5 2.5 0.0 1.0
# BsmtUnfSF_cat_3 0.0 0.0 0.0 1.0
# BsmtUnfSF_cat_4 0.0 0.0 0.0 1.0
# BsmtUnfSF_cat_5 0.0 0.0 0.0 0.0
# TotalBsmtSF_cat_1 0.0 0.0 0.0 1.0
# TotalBsmtSF_cat_2 -1.5 2.5 0.0 1.0
# TotalBsmtSF_cat_3 -1.5 2.5 0.0 1.0
# TotalBsmtSF_cat_4 0.0 0.0 0.0 1.0
# TotalBsmtSF_cat_5 0.0 0.0 0.0 1.0
# Heating_Floor 0.0 0.0 0.0 0.0
# Heating_GasA 1.0 1.0 0.0 1.0
# Heating_GasW 0.0 0.0 0.0 0.0
# Heating_Grav 0.0 0.0 0.0 0.0
# Heating_OthW 0.0 0.0 0.0 0.0
# Heating_Wall 0.0 0.0 0.0 0.0
# HeatingQC_Ex -1.5 2.5 0.0 1.0
# HeatingQC_Fa 0.0 0.0 0.0 1.0
# HeatingQC_Gd 0.0 0.0 0.0 1.0
# HeatingQC_Po 0.0 0.0 0.0 0.0
# HeatingQC_TA -1.5 2.5 0.0 1.0
# CentralAir_N 0.0 0.0 0.0 1.0
# CentralAir_Y 1.0 1.0 0.0 1.0
# Electrical_FuseA 0.0 0.0 0.0 1.0
# Electrical_FuseF 0.0 0.0 0.0 1.0
# Electrical_FuseP 0.0 0.0 0.0 0.0
# Electrical_Mix 0.0 0.0 0.0 0.0
# Electrical_SBrkr 1.0 1.0 0.0 1.0
# 1stFlrSF_cat_1 0.0 0.0 0.0 0.0
# 1stFlrSF_cat_2 -1.5 2.5 0.0 1.0
# 1stFlrSF_cat_3 -1.5 2.5 0.0 1.0
# 1stFlrSF_cat_4 0.0 0.0 0.0 1.0
# 1stFlrSF_cat_5 0.0 0.0 0.0 1.0
# 2ndFlrSF_cat_1 -1.5 2.5 0.0 1.0
# 2ndFlrSF_cat_2 -1.5 2.5 0.0 1.0
# 2ndFlrSF_cat_3 0.0 0.0 0.0 1.0
# 2ndFlrSF_cat_4 0.0 0.0 0.0 0.0
# LotFrontage_log 3.723012881732746 4.757308834907587 3.091042453358316 4.875197323201151
# LotArea_log 8.267831248396718 9.987594945304203 7.427144133408616 10.146796935470244
# BsmtUnfSF_log 3.4835305248818473 8.613240515757237 0.0 7.469654172932128
# Is_MasVnr -1.5 2.5 0.0 1.0
# Is_BsmtFinSF1 -1.5 2.5 0.0 1.0
# Is_BsmtFinSF2 0.0 0.0 0.0 1.0
# Is_BsmtUnfSF 1.0 1.0 0.0 1.0
# Is_TotalBsmtSF 1.0 1.0 0.0 1.0
# Is_2ndFlrSF -1.5 2.5 0.0 1.0
# Is_LowQualFinSF 0.0 0.0 0.0 1.0
# Is_GarageArea 1.0 1.0 0.0 1.0
# Is_WoodDeckSF -1.5 2.5 0.0 1.0
# Is_OpenPorchSF -1.5 2.5 0.0 1.0
# Is_EnclosedPorch 0.0 0.0 0.0 1.0
# Is_3SsnPorch 0.0 0.0 0.0 1.0
# Is_ScreenPorch 0.0 0.0 0.0 1.0
# LotFrontage_median_range -1.5 2.5 0.0 1.0
# LotFrontage_mean_range -1.5 2.5 0.0 1.0
# LotFrontage_q1 0.0 0.0 0.0 1.0
# LotFrontage_q3 0.0 0.0 0.0 1.0
# LotArea_median_range -1.5 2.5 0.0 1.0
# LotArea_mean_range -1.5 2.5 0.0 1.0
# LotArea_q1 0.0 0.0 0.0 1.0
# LotArea_q3 0.0 0.0 0.0 1.0
# MasVnrArea_median_range -1.5 2.5 0.0 1.0
# MasVnrArea_mean_range -1.5 2.5 0.0 1.0
# MasVnrArea_q1 0.0 0.0 0.0 0.0
# MasVnrArea_q3 0.0 0.0 0.0 1.0
# BsmtFinSF1_median_range -1.5 2.5 0.0 1.0
# BsmtFinSF1_mean_range -1.5 2.5 0.0 1.0
# BsmtFinSF1_q1 0.0 0.0 0.0 0.0
# BsmtFinSF1_q3 0.0 0.0 0.0 1.0
# BsmtFinSF2_median_range 0.0 0.0 0.0 1.0
# BsmtFinSF2_mean_range 0.0 0.0 0.0 1.0
# BsmtFinSF2_q1 0.0 0.0 0.0 0.0
# BsmtFinSF2_q3 0.0 0.0 0.0 1.0
# BsmtUnfSF_median_range -1.5 2.5 0.0 1.0
# BsmtUnfSF_mean_range -1.5 2.5 0.0 1.0
# BsmtUnfSF_q1 0.0 0.0 0.0 1.0
# BsmtUnfSF_q3 0.0 0.0 0.0 1.0
# TotalBsmtSF_median_range -1.5 2.5 0.0 1.0
# TotalBsmtSF_mean_range -1.5 2.5 0.0 1.0
# TotalBsmtSF_q1 0.0 0.0 0.0 1.0
# TotalBsmtSF_q3 0.0 0.0 0.0 1.0
# 1stFlrSF_median_range -1.5 2.5 0.0 1.0
# 1stFlrSF_mean_range -1.5 2.5 0.0 1.0
# 1stFlrSF_q1 0.0 0.0 0.0 1.0
# 1stFlrSF_q3 0.0 0.0 0.0 1.0
# 2ndFlrSF_median_range -1.5 2.5 0.0 1.0
# 2ndFlrSF_mean_range -1.5 2.5 0.0 1.0
# 2ndFlrSF_q1 0.0 0.0 0.0 0.0
# 2ndFlrSF_q3 0.0 0.0 0.0 1.0
# LowQualFinSF_median_range 0.0 0.0 0.0 1.0
# LowQualFinSF_mean_range 0.0 0.0 0.0 1.0
# LowQualFinSF_q1 0.0 0.0 0.0 0.0
# LowQualFinSF_q3 0.0 0.0 0.0 1.0
# GrLivArea_median_range -1.5 2.5 0.0 1.0
# GrLivArea_mean_range -1.5 2.5 0.0 1.0
# GrLivArea_q1 0.0 0.0 0.0 1.0
# GrLivArea_q3 0.0 0.0 0.0 1.0
# GarageYrBlt_median_range -1.5 2.5 0.0 1.0
# GarageYrBlt_mean_range 1.0 1.0 0.0 1.0
# GarageYrBlt_q1 0.0 0.0 0.0 1.0
# GarageYrBlt_q3 0.0 0.0 0.0 1.0
# GarageArea_median_range -1.5 2.5 0.0 1.0
# GarageArea_mean_range -1.5 2.5 0.0 1.0
# GarageArea_q1 0.0 0.0 0.0 1.0
# GarageArea_q3 0.0 0.0 0.0 1.0
# WoodDeckSF_median_range -1.5 2.5 0.0 1.0
# WoodDeckSF_mean_range -1.5 2.5 0.0 1.0
# WoodDeckSF_q1 0.0 0.0 0.0 0.0
# WoodDeckSF_q3 0.0 0.0 0.0 1.0
# OpenPorchSF_median_range -1.5 2.5 0.0 1.0
# OpenPorchSF_mean_range -1.5 2.5 0.0 1.0
# OpenPorchSF_q1 0.0 0.0 0.0 0.0
# OpenPorchSF_q3 0.0 0.0 0.0 1.0
# EnclosedPorch_median_range 0.0 0.0 0.0 1.0
# EnclosedPorch_mean_range 0.0 0.0 0.0 1.0
# EnclosedPorch_q1 0.0 0.0 0.0 0.0
# EnclosedPorch_q3 0.0 0.0 0.0 1.0
# 3SsnPorch_median_range 0.0 0.0 0.0 1.0
# 3SsnPorch_mean_range 0.0 0.0 0.0 1.0
# 3SsnPorch_q1 0.0 0.0 0.0 0.0
# 3SsnPorch_q3 0.0 0.0 0.0 1.0
# ScreenPorch_median_range 0.0 0.0 0.0 1.0
# ScreenPorch_mean_range 0.0 0.0 0.0 1.0
# ScreenPorch_q1 0.0 0.0 0.0 0.0
# ScreenPorch_q3 0.0 0.0 0.0 1.0
# BsmtFinSF2_sc_median_range 0.0 0.0 0.0 1.0
# BsmtFinSF2_sc_mean_range 0.0 0.0 0.0 1.0
# BsmtFinSF2_sc_q1 0.0 0.0 0.0 0.0
# BsmtFinSF2_sc_q3 0.0 0.0 0.0 1.0
# LowQualFinSF_sc_median_range 0.0 0.0 0.0 1.0
# LowQualFinSF_sc_mean_range 0.0 0.0 0.0 1.0
# LowQualFinSF_sc_q1 0.0 0.0 0.0 0.0
# LowQualFinSF_sc_q3 0.0 0.0 0.0 1.0
# WoodDeckSF_sc_median_range -1.5 2.5 0.0 1.0
# WoodDeckSF_sc_mean_range -1.5 2.5 0.0 1.0
# WoodDeckSF_sc_q1 0.0 0.0 0.0 0.0
# WoodDeckSF_sc_q3 0.0 0.0 0.0 1.0
# OpenPorchSF_sc_median_range -1.5 2.5 0.0 1.0
# OpenPorchSF_sc_mean_range -1.5 2.5 0.0 1.0
# OpenPorchSF_sc_q1 0.0 0.0 0.0 0.0
# OpenPorchSF_sc_q3 0.0 0.0 0.0 1.0
# EnclosedPorch_sc_median_range 0.0 0.0 0.0 1.0
# EnclosedPorch_sc_mean_range 0.0 0.0 0.0 1.0
# EnclosedPorch_sc_q1 0.0 0.0 0.0 0.0
# EnclosedPorch_sc_q3 0.0 0.0 0.0 1.0
# 3SsnPorch_sc_median_range 0.0 0.0 0.0 1.0
# 3SsnPorch_sc_mean_range 0.0 0.0 0.0 1.0
# 3SsnPorch_sc_q1 0.0 0.0 0.0 0.0
# 3SsnPorch_sc_q3 0.0 0.0 0.0 1.0
# ScreenPorch_sc_median_range 0.0 0.0 0.0 1.0
# ScreenPorch_sc_mean_range 0.0 0.0 0.0 1.0
# ScreenPorch_sc_q1 0.0 0.0 0.0 0.0
# ScreenPorch_sc_q3 0.0 0.0 0.0 1.0
# MiscVal_sc_median_range 0.0 0.0 0.0 1.0
# MiscVal_sc_mean_range 0.0 0.0 0.0 1.0
# MiscVal_sc_q1 0.0 0.0 0.0 0.0
# MiscVal_sc_q3 0.0 0.0 0.0 1.0
# AllSF_median_range -1.5 2.5 0.0 1.0
# AllSF_mean_range -1.5 2.5 0.0 1.0
# AllSF_q1 0.0 0.0 0.0 1.0
# AllSF_q3 0.0 0.0 0.0 1.0
# Area_median_range -1.5 2.5 0.0 1.0
# Area_mean_range -1.5 2.5 0.0 1.0
# Area_q1 0.0 0.0 0.0 1.0
# Area_q3 0.0 0.0 0.0 1.0
# Area_log_median_range -1.5 2.5 0.0 1.0
# Area_log_mean_range -1.5 2.5 0.0 1.0
# Area_log_q1 0.0 0.0 0.0 1.0
# Area_log_q3 0.0 0.0 0.0 1.0
# LotFrontage_log_median_range -1.5 2.5 0.0 1.0
# LotFrontage_log_mean_range -1.5 2.5 0.0 1.0
# LotFrontage_log_q1 0.0 0.0 0.0 1.0
# LotFrontage_log_q3 0.0 0.0 0.0 1.0
# LotArea_log_median_range -1.5 2.5 0.0 1.0
# LotArea_log_mean_range -1.5 2.5 0.0 1.0
# LotArea_log_q1 0.0 0.0 0.0 1.0
# LotArea_log_q3 0.0 0.0 0.0 1.0
# BsmtUnfSF_log_median_range -1.5 2.5 0.0 1.0
# BsmtUnfSF_log_mean_range -1.5 2.5 0.0 1.0
# BsmtUnfSF_log_q1 0.0 0.0 0.0 1.0
# BsmtUnfSF_log_q3 0.0 0.0 0.0 1.0

# %%
df.shape
# Out:
# (2797, 792)

# %%
#creating matrices for feature selection:
X_train = df[:train.shape[0]]
X_test_fin = df[train.shape[0]:]
y = train.SalePrice
X_train['Y'] = y
df = X_train
df.head(20) ## DF for Model training

X = df.drop('Y', axis=1)
y = df.Y

# %%
# import xgboost as xgb
# from sklearn.metrics import r2_score

# from sklearn.model_selection import RandomizedSearchCV

# xg_cl = xgb.XGBClassifier()
# param = {'max_depth':[3,4],
#          'learning_rate':[0.01,0.03],
#          'min_child_weight':[1,3],
#          'reg_lambda':[0.1,0.5],
#          'reg_alpha':[1,1.5],      
#          'gamma':[0.1,0.5],
#          'subsample':[0.4,0.5],
#         'colsample_bytree':[0.4,0.5],
# }
# clf = RandomizedSearchCV(xg_cl,param,verbose=10)

# clf.fit(X,y)
# print('Best roc_auc: {:.4}, with best params: {}'.format(clf.best_score_, clf.best_params_))

# %%
import xgboost as xgb
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split


X = df.drop('Y', axis=1)
y = df.Y



params = {
        'objective':'reg:linear',
        'n_estimators': 1000,
        'booster':'gbtree',
        'max_depth':2,
        'eval_metric':'mae',
        'learning_rate':0.005, 
        'min_child_weight':2,
        'subsample':0.7,
        'colsample_bytree':0.8,
        'seed':45,
        'reg_alpha':1,
        'gamma':0,
        'nthread':-1

}


x_train, x_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=10)

d_train = xgb.DMatrix(x_train, label=y_train)
d_valid = xgb.DMatrix(x_valid, label=y_valid)
d_test = xgb.DMatrix(X_test_fin)

watchlist = [(d_train, 'train'), (d_valid, 'valid')]

clf = xgb.train(params, d_train, 10000, watchlist, early_stopping_rounds=50, maximize=False, verbose_eval=10)

p_test = clf.predict(d_test)

# cv_result = xgb.cv(params, 
#                   d_train, 
#                   num_boost_round=2000, # increase to have better results (~700)
#                   early_stopping_rounds=50,
#                   verbose_eval=10, 
#                   show_stdv=False
#                  )
# Out:
# [10:53:59] WARNING: /workspace/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [10:53:59] WARNING: /workspace/src/learner.cc:480:
# Parameters: { n_estimators } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train
# [6440]	train-mae:8947.89453	valid-mae:12535.98535
# [6450]	train-mae:8941.79688	valid-mae:12534.88574
# [6460]	train-mae:8938.19238	valid-mae:12532.59473
# [6470]	train-mae:8932.81641	valid-mae:12528.26074
# [6480]	train-mae:8927.53125	valid-mae:12526.77637
# [6490]	train-mae:8922.34180	valid-mae:12523.76758
# [6500]	train-mae:8917.74316	valid-mae:12520.82422
# [6510]	train-mae:8911.87500	valid-mae:12521.68066
# [6520]	train-mae:8905.79785	valid-mae:12515.09375
# [6530]	train-mae:8902.34082	valid-mae:12512.80273
# [6540]	train-mae:8897.35254	valid-mae:12511.05176
# [6550]	train-mae:8893.38769	valid-mae:12509.73926
# [6560]	train-mae:8887.71191	valid-mae:12508.68652
# [6570]	train-mae:8881.86914	valid-mae:12507.42188
# [6580]	train-mae:8876.16504	valid-mae:12504.43652
# [6590]	train-mae:8870.61621	valid-mae:12503.77539
# [6600]	train-mae:8866.03711	valid-mae:12500.81738
# [6610]	train-mae:8859.99121	valid-mae:12496.38379
# [6620]	train-mae:8855.51074	valid-mae:12496.04297
# [6630]	train-mae:8850.06250	valid-mae:12496.47070
# [6640]	train-mae:8844.64648	valid-mae:12498.60547
# [6650]	train-mae:8839.77539	valid-mae:12500.21875
# [6660]	train-mae:8833.88281	valid-mae:12495.74023
# [6670]	train-mae:8829.84766	valid-mae:12493.21875
# [6680]	train-mae:8825.58984	valid-mae:12492.31445
# [6690]	train-mae:8821.53516	valid-mae:12490.60449
# [6700]	train-mae:8816.16894	valid-mae:12489.38184
# [6710]	train-mae:8811.37012	valid-mae:12486.99512
# [6720]	train-mae:8807.20312	valid-mae:12486.82422
# [6730]	train-mae:8803.59961	valid-mae:12487.65137
# [6740]	train-mae:8799.84473	valid-mae:12487.28809
# [6750]	train-mae:8795.83106	valid-mae:12486.17676
# [6760]	train-mae:8789.76856	valid-mae:12484.30371
# [6770]	train-mae:8786.41211	valid-mae:12483.23926
# [6780]	train-mae:8782.49609	valid-mae:12487.42676
# [6790]	train-mae:8777.35840	valid-mae:12482.99902
# [6800]	train-mae:8773.22559	valid-mae:12483.60254
# [6810]	train-mae:8766.58691	valid-mae:12478.34375
# [6820]	train-mae:8762.33398	valid-mae:12477.20410
# [6830]	train-mae:8758.69043	valid-mae:12478.05566
# [6840]	train-mae:8753.55664	valid-mae:12479.45703
# [6850]	train-mae:8748.56055	valid-mae:12479.68457
# [6860]	train-mae:8744.34473	valid-mae:12478.88769
# [6870]	train-mae:8738.37695	valid-mae:12478.45019
# Stopping. Best iteration:
# [6825]	train-mae:8760.47852	valid-mae:12476.09668
#
# [10:56:14] WARNING: /workspace/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.

# %%
leaks = {
    1461:105000,
1477:290941,
1492:67500,
1494:362500,
1514:84900,
1521:108538,
1531:80400,
1537:12789,
1540:76500,
1545:134000,
1554:122000,
1556:107500,
1557:100000,
1559:93369,
1560:114900,
1566:270000,
1567:85000,
1572:128000,
1573:308030,
1575:270000,
1586:84900,
1587:155891,
1589:64000,
1595:100000,
1597:215000,
1603:50138,
1610:174000,
1611:169000,
1615:76000,
1616:88250,
1617:85500,
1620:159000,
1622:161000,
1631:240000,
1638:154000,
1650:76500,
1652:111000,
1661:462000,
1664:610000,
1666:296000,
1678:552000,
1696:245000,
1698:327000,
1712:264500,
1717:152000,
1720:203000,
1726:171500,
1727:145000,
1737:275000,
1767:256000,
1774:135000,
1786:142900,
1787:156500,
1788:59000,
1790:78500,
1793:163000,
1807:103500,
1814:80000,
1820:58500,
1823:44000,
1831:179900,
1832:62500,
1835:97500,
1837:70000,
1842:63000,
1843:113500,
1863:269500,
1864:269500,
1892:85000,
1895:103500,
1912:315000,
1913:123000,
1915:230000,
1916:57625,
1925:170000,
1946:115000,
1947:334000,
1967:317500,
1970:390000,
1971:460000,
1975:615000,
1976:284000,
1996:284500,
1997:291000,
2004:297900,
2014:163000,
2030:300000,
2031:285000,
2032:290000,
2033:305000,
2038:345000,
2052:140000,
2055:141500,
2068:146000,
2076:94000,
2086:143000,
2093:122250,
2099:46500,
2100:65000,
2101:139500,
2106:55000,
2107:184000,
2111:108000,
2152:260000,
2162:475000,
2163:395039,
2180:185000,
2185:165000,
2206:104000,
2207:257076,
2208:263400,
2211:126000,
2217:13100,
2220:65000,
2223:300000,
2227:241500,
2230:172500,
2232:150000,
2235:195000,
2236:298751,
2238:209200,
2239:146000,
2245:94900,
2251:103000,
2263:349265,
2264:591587,
2267:441929,
2268:455000,
2269:174000,
2288:322400,
2295:500067,
2342:260000,
2354:146000,
2362:300000,
2375:279700,
2376:255000,
2379:240050,
2380:162500,
2395:224500,
2404:175000,
2419:115000,
2437:125500,
2455:136500,
2461:132000,
2465:165000,
2466:90000,
2468:113000,
2469:117000,
2474:50000,
2495:109900,
2544:110000,
2550:183850,
2557:79275,
2564:238000,
2565:153500,
2572:200000,
2574:315000,
2583:375000,
2590:244000,
2591:257000,
2599:392000,
2610:138000,
2611:80000,
2617:169000,
2618:252000,
2627:130000,
2631:535000,
2632:401179,
2634:470000,
2638:294323,
2658:344133,
2673:246990,
2690:405749,
2702:129500,
2723:157500,
2741:132000,
2752:167000,
2754:180000,
2760:80000,
2775:111500,
2776:156500,
2779:111500,
2788:64000,
2793:202500,
2794:75000,
2805:125000,
2813:156500,
2823:415000,
2829:224500,
2832:233555,
2859:98000,
2866:134000,
2872:35000,
2873:121000,
2881:195000,
2916:71000,
2917:131000,
2919:188000
}

# %%
sub = pd.DataFrame()
sub['Id'] = test['Id']
sub['SalePrice'] = p_test
sub['SalePrice'] = sub.apply(lambda r: leaks[int(r['Id'])] if int(r['Id']) in leaks else r['SalePrice'], axis=1)
sub.to_csv('submission.csv', index=False)

# %%
sub
# Out:
#         Id      SalePrice
# 0     1461  105000.000000
# 1     1462  166257.093750
# 2     1463  198106.703125
# 3     1464  196095.156250
# 4     1465  190081.484375
# ...    ...            ...
# 1454  2915   90989.421875
# 1455  2916   71000.000000
# 1456  2917  131000.000000
# 1457  2918  117608.117188
# 1458  2919  188000.000000
#
# [1459 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
# plot the important features #
fig, ax = plt.subplots(figsize=(12,18))
xgb.plot_importance(clf, max_num_features=50, height=0.8, ax=ax)
plt.show()
